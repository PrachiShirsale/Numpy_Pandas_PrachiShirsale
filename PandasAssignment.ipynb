# %% [markdown]
# Q1. Read superstore data

# %%
import pandas as pd 

df = pd.read_excel("Superstore.xls")

df.head()
# Out:
#     no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# Q2. Find the index of the data

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# Q3. Find the columns of the data

# %%
print(df.columns)
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# Q4. If columns name is having space then remove the space and rename the column. Find various ways to rename the columns.

# %%
RemoveSpace = df.columns.str.replace(" ", ",")
print(RemoveSpace)
# Out:
# Index(['no', 'order,_id', 'Order,Date', 'Ship,Date', 'Ship,Mode',
#        'Customer,ID', 'Customer,Name', 'Segment', 'Country', 'City', 'State',
#        'Postal,Code', 'Region', 'Product,ID', 'Category', 'Sub-Category',
#        'Product,Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# Q5. Display First 40 Records

# %%
df.head(40)
# Out:
#       no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# Q6 Display last 15 records from the data

# %%
df.tail(15)
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# Q7. Change the setting to display minimum 30 rows for given data

# %%
pd.set_option('display.min_rows',30) 
# 15 rows from begining and 15 rows from end will be displayed.

df
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11      12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12      13.0  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...

# %% [markdown]
# Q8. Change the Display setting to minimum row as 3

# %%
pd.set_option('display.min_rows' , 3)
df
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# Q9. Take a slice from the dataframe based on the columns city, state, region, profit columns

# %%
SlicedDf = df[['City' , 'State' , 'Region', 'Profit']]  # '[[ , ,]]' only the columns will be displayed
SlicedDf
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# Q10. Take a slice based on data availabe at 1000 to 1500 position and columns from 4 to 8

# %%
df.iloc[1000 : 1500 , 4:9]
# Out:
#            Ship Mode Customer ID  Customer Name      Segment        Country
# 1000  Standard Class    FM-14290   Frank Merwin  Home Office  United States
# ...              ...         ...            ...          ...            ...
# 1499  Standard Class    NG-18430  Nathan Gelder     Consumer  United States
#
# [500 rows x 5 columns]

# %% [markdown]
# Q11. Rename the index starts from 1900 to end of the data

# %%
df.index = range(1900, 1900 + len(df))

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# Q12. Take a slice from data based on index having name as 1920 , 1940, 1945, 1980, and columns as profit, state, category, sub-category, region

# %%
for index, column in enumerate(df.columns):
    print(f"Col : {column} Ind : {index}")

# df.iloc[[1920, 1940, 1945, 1980], ['Profit' , 'state' , 'Category' , 'Sub-Category', 'Region']]
df.iloc[[1920, 1940, 1945, 1980], [ 20, 10 , 14 , 15, 12]]
# Out:
# Col : no Ind : 0
# Col : order _id Ind : 1
# Col : Order Date Ind : 2
# Col : Ship Date Ind : 3
# Col : Ship Mode Ind : 4
# Col : Customer ID Ind : 5
# Col : Customer Name Ind : 6
# Col : Segment Ind : 7
# Col : Country Ind : 8
# Col : City Ind : 9
# Col : State Ind : 10
# Col : Postal Code Ind : 11
# Col : Region Ind : 12
# Col : Product ID Ind : 13
# Col : Category Ind : 14
# Col : Sub-Category Ind : 15
# Col : Product Name Ind : 16
# Col : Sales Ind : 17
# Col : Quantity Ind : 18
# Col : Discount Ind : 19
# Col : Profit Ind : 20
#        Profit     State         Category Sub-Category   Region
# 3820  97.6524  New York        Furniture       Chairs     East
# 3840  74.5740  Colorado        Furniture       Chairs     West
# 3845   3.6288     Texas  Office Supplies        Paper  Central
# 3880   4.2976   Arizona  Office Supplies      Storage     West

# %% [markdown]
# Q13. Check the data type of columns

# %%
for i in df.columns:
    print(f"Column Name: {i} DataType : {df[i].dtypes}")
# Out:
# Column Name: no DataType : float64
# Column Name: order _id DataType : object
# Column Name: Order Date DataType : datetime64[ns]
# Column Name: Ship Date DataType : datetime64[ns]
# Column Name: Ship Mode DataType : object
# Column Name: Customer ID DataType : object
# Column Name: Customer Name DataType : object
# Column Name: Segment DataType : object
# Column Name: Country DataType : object
# Column Name: City DataType : object
# Column Name: State DataType : object
# Column Name: Postal Code DataType : int64
# Column Name: Region DataType : object
# Column Name: Product ID DataType : object
# Column Name: Category DataType : object
# Column Name: Sub-Category DataType : object
# Column Name: Product Name DataType : object
# Column Name: Sales DataType : float64
# Column Name: Quantity DataType : int64
# Column Name: Discount DataType : float64
# Column Name: Profit DataType : float64

# %% [markdown]
# Q14. Find out the record for the month of jun-2014

# %%
Jun14Record = df[(df['Order Date'].dt.year == 2014) & (df['Order Date'].dt.month == 6)] 
Jun14Record
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer ID      Customer Name   Segment        Country         City  \
# 1905     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...           ...                ...       ...            ...          ...
# 11796    JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... Postal Code   Region       Product ID         Category  \
# 1905   ...       90032     West  FUR-FU-10001487        Furniture
# ...    ...         ...      ...              ...              ...
# 11796  ...       60653  Central  OFF-PA-10001725  Office Supplies
#
#       Sub-Category                                       Product Name   Sales  \
# ...

# %% [markdown]
# Q15. Calculate month wise average of profit.

# %%
df.set_index('Order Date', inplace = True)  #--> Error!! 
MonthAvg = df.resample('M')['Profit'].mean()  

MonthAvg
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18272\140932573.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   MonthAvg = df.resample('M')['Profit'].mean()
# Order Date
# 2014-01-31    31.015072
# 2014-02-28    18.745835
# 2014-03-31     3.176624
# 2014-04-30    25.843224
# 2014-05-31    22.448439
# 2014-06-30    36.863144
# 2014-07-31    -5.884494
# 2014-08-31    34.758856
# 2014-09-30    31.074998
# 2014-10-31    21.687153
# 2014-11-30    29.220525
# 2014-12-31    32.315000
# 2015-01-31   -56.569086
# 2015-02-28    43.966419
# 2015-03-31    70.522448
# 2015-04-30    26.171851
# 2015-05-31    31.971705
# 2015-06-30    24.170704
# 2015-07-31    23.490345
# 2015-08-31    33.684330
# 2015-09-30    28.017620
# 2015-10-31    16.972084
# 2015-11-30    38.502433
# 2015-12-31    25.370145
# 2016-01-31    31.739588
# 2016-02-29    60.296139
# 2016-03-31    22.159313
# 2016-04-30    17.516558
# 2016-05-31    38.498428
# ...

# %% [markdown]
# Q16. Create the new data frame for California

# %%
CalDf = df[df['State'] == 'California']
CalDf
# Out:
#                 no       order _id  Ship Date     Ship Mode Customer ID  \
# Order Date
# 2016-06-12     3.0  CA-2016-138688 2016-06-16  Second Class    DV-13045
# ...            ...             ...        ...           ...         ...
# 2017-05-04  9994.0  CA-2017-119914 2017-05-09  Second Class    CC-12220
#
#               Customer Name    Segment        Country         City  \
# Order Date
# 2016-06-12  Darrin Van Huff  Corporate  United States  Los Angeles
# ...                     ...        ...            ...          ...
# 2017-05-04     Chris Cortes   Consumer  United States  Westminster
#
#                  State  Postal Code Region       Product ID         Category  \
# Order Date
# 2016-06-12  California        90036   West  OFF-LA-10000240  Office Supplies
# ...                ...          ...    ...              ...              ...
# 2017-05-04  California        92683   West  OFF-AP-10002684  Office Supplies
#
# ...

# %% [markdown]
# Q17. Find sum of sales

# %%
salesSum = df['Sales'].sum()
salesSum
# Out:
# np.float64(2297200.8603000003)

# %% [markdown]
# Q18. Find state wise sum of sales.

# %%
stateSalesSum = df.groupby('State')['Sales'].sum()
stateSalesSum
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# Q19. Find month wise sum of sales

# %%
# df.set_index('Order Date', inplace=True)
monthSalesSum = df.resample('M')['Sales'].sum()
monthSalesSum
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18272\922248387.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthSalesSum = df.resample('M')['Sales'].sum()
# Order Date
# 2014-01-31     14236.8950
# 2014-02-28      4519.8920
# 2014-03-31     55691.0090
# 2014-04-30     28295.3450
# 2014-05-31     23648.2870
# 2014-06-30     34595.1276
# 2014-07-31     33946.3930
# 2014-08-31     27909.4685
# 2014-09-30     81777.3508
# 2014-10-31     31453.3930
# 2014-11-30     78628.7167
# 2014-12-31     69545.6205
# 2015-01-31     18174.0756
# 2015-02-28     11951.4110
# 2015-03-31     38726.2520
# 2015-04-30     34195.2085
# 2015-05-31     30131.6865
# 2015-06-30     24797.2920
# 2015-07-31     28765.3250
# 2015-08-31     36898.3322
# 2015-09-30     64595.9180
# 2015-10-31     31404.9235
# 2015-11-30     75972.5635
# 2015-12-31     74919.5212
# 2016-01-31     18542.4910
# 2016-02-29     22978.8150
# 2016-03-31     51715.8750
# ...

# %% [markdown]
# Q20. Find country wise and city wise average profit

# %%
ConCitAvgP = df.groupby(['Country', 'City'])['Profit'].mean()
ConCitAvgP
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# Q21. Calculate region wise average profit.

# %%
RegAvgP = df.groupby(['Region'])['Profit'].mean()
RegAvgP
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# Q22. Find the ship mode which is more profitable.

# %%
ShipModeP = df.groupby(['Ship Mode'])['Profit'].sum()
MaxP = ShipModeP.idxmax()

MaxP
# Out:
# 'Standard Class'

# %% [markdown]
# Q23. Create a new data frame where loss is recorded

# %%
lossdf = df[df['Profit'] < 0]
lossdf
# Out:
#                 no       order _id  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2015-10-11     4.0  US-2015-108966 2015-10-18  Standard Class    SO-20335
# ...            ...             ...        ...             ...         ...
# 2015-03-19  9963.0  CA-2015-168088 2015-03-22     First Class    CM-12655
#
#                Customer Name      Segment        Country             City  \
# Order Date
# 2015-10-11    Sean O'Donnell     Consumer  United States  Fort Lauderdale
# ...                      ...          ...            ...              ...
# 2015-03-19  Corinna Mitchell  Home Office  United States          Houston
#
#               State  Postal Code   Region       Product ID   Category  \
# Order Date
# 2015-10-11  Florida        33311    South  FUR-TA-10000577  Furniture
# ...             ...          ...      ...              ...        ...
# 2015-03-19    Texas        77041  Central  FUR-BO-10004218  Furniture
#
# ...

# %% [markdown]
# Q24. Find category wise sub category wise sales

# %%
CSSales = df.groupby(['Category', 'Sub-Category'])['Sales'].sum()
CSSales
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# Q25. Create a data frame for record where discount is 0

# %%
dsc = df[df['Discount'] == 0]
dsc
# Out:
#                 no       order _id  Ship Date     Ship Mode Customer ID  \
# Order Date
# 2016-11-08     NaN             NaN 2016-11-11  Second Class    CG-12520
# ...            ...             ...        ...           ...         ...
# 2017-05-04  9994.0  CA-2017-119914 2017-05-09  Second Class    CC-12220
#
#            Customer Name   Segment        Country         City       State  \
# Order Date
# 2016-11-08   Claire Gute  Consumer  United States    Henderson    Kentucky
# ...                  ...       ...            ...          ...         ...
# 2017-05-04  Chris Cortes  Consumer  United States  Westminster  California
#
#             Postal Code Region       Product ID         Category Sub-Category  \
# Order Date
# 2016-11-08        42420  South  FUR-BO-10001798        Furniture    Bookcases
# ...                 ...    ...              ...              ...          ...
# 2017-05-04        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
# ...

# %% [markdown]
# Q26. Create a data frame where order date and ship date
# both are in JAN-2014

# %%
Jan14 = df[(df['Order Date'] == '2014-01') & (df['Ship Date'] == '2014-01')]  # Error --> Order Date Column!!
Jan14
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[209], line 1
# ...

# %% [markdown]
# Q27. Find records having profit for consumer segment.

# %%
consPR = df[(df['Segment'] == 'Consumer') & (df['Profit'] > 0)]
consPR
# Out:
#                 no       order _id  Ship Date     Ship Mode Customer ID  \
# Order Date
# 2016-11-08     NaN             NaN 2016-11-11  Second Class    CG-12520
# ...            ...             ...        ...           ...         ...
# 2017-05-04  9994.0  CA-2017-119914 2017-05-09  Second Class    CC-12220
#
#            Customer Name   Segment        Country         City       State  \
# Order Date
# 2016-11-08   Claire Gute  Consumer  United States    Henderson    Kentucky
# ...                  ...       ...            ...          ...         ...
# 2017-05-04  Chris Cortes  Consumer  United States  Westminster  California
#
#             Postal Code Region       Product ID         Category Sub-Category  \
# Order Date
# 2016-11-08        42420  South  FUR-BO-10001798        Furniture    Bookcases
# ...                 ...    ...              ...              ...          ...
# 2017-05-04        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
# ...

# %% [markdown]
# Q28. Generate new data frame for every state. hint : dynamic variable creation

# %%
StateDf = {}
for state in df['State'].unique():
    StateDf[state] = df[df['State'] == state]

StateDf
# Out:
# {'Kentucky':                 no       order _id  Ship Date     Ship Mode Customer ID  \
#  Order Date
#  2016-11-08     NaN             NaN 2016-11-11  Second Class    CG-12520
#  ...            ...             ...        ...           ...         ...
#  2017-09-16  9961.0  CA-2017-141446 2017-09-18  Second Class    CL-12700
#
#             Customer Name      Segment        Country       City     State  \
#  Order Date
#  2016-11-08   Claire Gute     Consumer  United States  Henderson  Kentucky
#  ...                  ...          ...            ...        ...       ...
#  2017-09-16  Craig Leslie  Home Office  United States   Florence  Kentucky
#
#              Postal Code Region       Product ID    Category Sub-Category  \
#  Order Date
#  2016-11-08        42420  South  FUR-BO-10001798   Furniture    Bookcases
#  ...                 ...    ...              ...         ...          ...
#  2017-09-16        41042  South  TEC-AC-10002305  Technology  Accessories
#
# ...

# %% [markdown]
# Q29. Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
RegStateAvg = df.groupby(['Region', 'State'])[['Profit', 'Sales']].mean()
RegStateAvg
# Out:
#                                   Profit        Sales
# Region  State
# Central Illinois              -25.625787   162.939230
#         Indiana               123.375411   359.431946
#         Iowa                   39.460397   152.658667
#         Kansas                 34.851813   121.429583
#         Michigan               95.934069   299.096525
#         Minnesota             121.608847   335.541011
#         Missouri               97.518341   336.441667
#         Nebraska               53.607742   196.445526
#         North Dakota           32.878529   131.415714
#         Oklahoma               73.544788   298.233182
#         South Dakota           32.902358   109.630000
#         Texas                 -26.121174   172.779742
#         Wisconsin              76.380004   291.951000
# East    Connecticut            42.823071   163.223866
#         Delaware              103.930988   285.948635
#         District of Columbia  105.958930   286.502000
# ...

# %%
EastAvg = RegStateAvg.loc['East']
EastAvg
# Out:
#                           Profit       Sales
# State
# Connecticut            42.823071  163.223866
# Delaware              103.930988  285.948635
# District of Columbia  105.958930  286.502000
# Maine                  56.810775  158.816250
# Maryland               66.963608  225.766886
# Massachusetts          50.262975  212.106919
# New Hampshire          63.203807  270.093481
# New Jersey             75.176260  275.110092
# New York               65.637011  275.599531
# Ohio                  -36.186304  166.861697
# Pennsylvania          -26.507598  198.487077
# Rhode Island          130.100523  404.070643
# Vermont               204.088936  811.760909
# West Virginia          46.480400  302.456000

# %% [markdown]
# Q30. Find all record for furniture delivered in Texas

# %%
FurTexRec = df[(df['Category'] == 'Furniture') & (df['State'] == 'Texas')]
FurTexRec
# Out:
#                 no       order _id  Ship Date    Ship Mode Customer ID  \
# Order Date
# 2016-12-08    37.0  CA-2016-117590 2016-12-10  First Class    GH-14485
# ...            ...             ...        ...          ...         ...
# 2015-03-19  9963.0  CA-2015-168088 2015-03-22  First Class    CM-12655
#
#                Customer Name      Segment        Country        City  State  \
# Order Date
# 2016-12-08         Gene Hale    Corporate  United States  Richardson  Texas
# ...                      ...          ...            ...         ...    ...
# 2015-03-19  Corinna Mitchell  Home Office  United States     Houston  Texas
#
#             Postal Code   Region       Product ID   Category Sub-Category  \
# Order Date
# 2016-12-08        75080  Central  FUR-FU-10003664  Furniture  Furnishings
# ...                 ...      ...              ...        ...          ...
# 2015-03-19        77041  Central  FUR-BO-10004218  Furniture    Bookcases
#
# ...
